# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1

chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
most=chipo[['item_name','quantity']].groupby('item_name')["quantity"].sum().sort_values(ascending=False).reset_index()
most
# Out:
#                                 item_name  quantity
# 0                            Chicken Bowl       761
# 1                         Chicken Burrito       591
# 2                     Chips and Guacamole       506
# 3                           Steak Burrito       386
# 4                       Canned Soft Drink       351
# 5                                   Chips       230
# 6                              Steak Bowl       221
# 7                           Bottled Water       211
# 8            Chips and Fresh Tomato Salsa       130
# 9                             Canned Soda       126
# 10                     Chicken Salad Bowl       123
# 11                     Chicken Soft Tacos       120
# 12                          Side of Chips       110
# 13                         Veggie Burrito        97
# 14                       Barbacoa Burrito        91
# 15                            Veggie Bowl        87
# 16                          Carnitas Bowl        71
# ...

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
print(most.loc[0,'quantity'])
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %% [markdown]
# tried two ways :

# %%
chipo["choice_description"].value_counts().sort_values(ascending=False)
# Out:
# choice_description
# [Diet Coke]                                                                                                                     134
# [Coke]                                                                                                                          123
# [Sprite]                                                                                                                         77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                           42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                40
#                                                                                                                                ...
# [Roasted Chili Corn Salsa, [Rice, Fajita Vegetables]]                                                                             1
# ...

# %%
choices = chipo["choice_description"].to_list()
desc_list = [[item.strip() for item in str(x).split(",")] for x in choices]
pd.Series(desc_list).value_counts()
# Out:
# [nan]                                                                                                   1246
# [[Diet Coke]]                                                                                            134
# [[Coke]]                                                                                                 123
# [[Sprite]]                                                                                                77
# [[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]]                                  42
#                                                                                                         ...
# [[Tomatillo Red Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Guacamole]]]       1
# [[Roasted Chili Corn Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]]                               1
# [[Roasted Chili Corn Salsa, [Pinto Beans, Sour Cream, Cheese, Lettuce, Guacamole]]]                        1
# ...

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo["quantity"].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %%
chipo["item_price_float"] = chipo["item_price"].str.replace("$","").astype(float)

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
print(chipo["item_price_float"].dtypes)
print(chipo["item_price"].dtypes)
# Out:
# float64
# str

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo["item_price"]= chipo["item_price"].apply(lambda x : float(x.replace('$','')))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo["item_price"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo["revenue"] = chipo["item_price"]* chipo['quantity']
print(chipo["revenue"].head())
print(chipo["revenue"].sum())
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    33.96
# Name: revenue, dtype: float64
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
orders = chipo["order_id"].nunique()

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
chipo.groupby("order_id")["revenue"].sum().mean()
# Out:
# np.float64(21.39423118865867)

# %%
# Solution 2
mean = chipo["revenue"].sum() / orders
mean
# Out:
# np.float64(21.39423118865867)

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo["item_name"].nunique()
# Out:
# 50
